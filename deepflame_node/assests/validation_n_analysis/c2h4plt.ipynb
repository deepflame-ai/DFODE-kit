# %%
import cantera as ct
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
plt.rc('font',family='Times New Roman')

# %%
  #指定全局字体
phi=np.array([0.8,0.9,1.0,1.1,1.2])     #| 4.73 | 4.92 | 5.36 | 5.73 | 6.03 |
flameSpeedcv = np.array([4.73,4.96,5.4,5.77,6.07])   
flameSpeeddnn = np.array([4.69,4.92,5.36,5.73,6.03]) 

plt.axis((0.75,1.25,0,10))
plt.rcParams['xtick.direction'] = 'in'#将x轴的刻度线方向设置向内
plt.rcParams['ytick.direction'] = 'in'#将y轴的刻度线方向设置向内
plt.plot(phi,flameSpeedcv,color='black')
plt.scatter(phi,flameSpeeddnn, marker='s',s=60,label='500K',edgecolors='black',color='none',linewidth=2)

plt.rc('font',family='Times New Roman')  #指定全局字体
phi=np.array([0.8,0.9,1.0,1.1,1.2])     #| 4.73 | 4.92 | 5.36 | 5.73 | 6.03 |
flameSpeed3cv = np.array([1.74,2.08,2.36,2.59,2.78])   
flameSpeed3dnn = np.array([1.74,2.08,2.36,2.59,2.78]) 
plt.plot(phi,flameSpeed3cv,color='r')
plt.scatter(phi,flameSpeed3dnn, marker='o',s=60,label='300K',edgecolors='r',color='none',linewidth=2)



plt.xticks((np.arange(8,13))*0.1,fontsize=20)
plt.yticks((np.arange(0,6))*2,fontsize=20)
plt.minorticks_on()  #minor
plt.gca().xaxis.set_minor_locator(ticker.MultipleLocator(0.1))
plt.gca().yaxis.set_minor_locator(ticker.MultipleLocator(1))

plt.xlabel('Equivalence ratio',fontsize=22,fontweight='bold')  #加粗
plt.ylabel('Laminar flame speed [m/s]',fontsize=22,fontweight='bold')
plt.rcParams.update({'font.size': 25})
plt.legend(frameon=False, loc=2)

# %%
plt.rc('font',family='Times New Roman')  #指定全局字体
phi=np.array([0.8,0.9,1.0,1.1,1.2])     #| 4.73 | 4.92 | 5.36 | 5.73 | 6.03 |
flameSpeed3cv = np.array([1.74,2.08,2.36,2.59,2.78])   
flameSpeed3dnn = np.array([1.74,2.08,2.36,2.59,2.78]) 

plt.axis((0.75,1.25,0,4))
plt.rcParams['xtick.direction'] = 'in'#将x轴的刻度线方向设置向内
plt.rcParams['ytick.direction'] = 'in'#将y轴的刻度线方向设置向内
plt.plot(phi,flameSpeed3cv,color='black')
plt.scatter(phi,flameSpeed3dnn, marker='s',s=60,edgecolors='black',color='none',linewidth=2)
plt.xticks((np.arange(8,13))*0.1,fontsize=16)
plt.yticks((np.arange(0,5))*1,fontsize=16)
plt.minorticks_on()  #minor
plt.gca().xaxis.set_minor_locator(ticker.MultipleLocator(0.1))
plt.gca().yaxis.set_minor_locator(ticker.MultipleLocator(0.5))

plt.xlabel('Equivalence ratio',fontsize=22,fontweight='bold')  #加粗
plt.ylabel('Laminar flame speed [m/s]',fontsize=22,fontweight='bold')
plt.rcParams.update({'font.size': 25})
plt.legend(frameon=False, loc=2)
plt.savefig("../../../../graph/H2",dpi=300)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
phi=np.array([0.8,0.9,1.0,1.1,1.2])
flameSpeedcv = np.array([1.9,2.06,2.14,2.15,2.07])   
flameSpeeddnn = np.array([1.9,2.06,2.14,2.15,2.07]) 




plt.axis((0.75,1.25,1.6,2.4))
plt.rcParams['xtick.direction'] = 'in'#将x轴的刻度线方向设置向内
plt.rcParams['ytick.direction'] = 'in'#将y轴的刻度线方向设置向内
plt.plot(phi,flameSpeedcv,color='black')
plt.scatter(phi,flameSpeeddnn,s=60, marker='s',edgecolors='black',color='none',linewidth=2)
plt.xticks((np.arange(8,13))*0.1,fontsize=20)
plt.yticks((np.arange(8,13))*0.2,fontsize=20)
plt.minorticks_on()  #minor
plt.gca().xaxis.set_minor_locator(ticker.MultipleLocator(0.1))
plt.gca().yaxis.set_minor_locator(ticker.MultipleLocator(0.1))

plt.xlabel('Equivalence ratio',fontsize=22,fontweight='bold')  #加粗
plt.ylabel('Laminar flame speed [m/s]',fontsize=22,fontweight='bold')
plt.rcParams.update({'font.size': 25})
plt.legend(frameon=False, loc=2)
plt.savefig("../../../../graph/HyChems/POSF-1d-LFS.png",dpi=300)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.rc('font',family='Times New Roman')  #指定全局字体
time=0.002
##选择时间点t
a=np.loadtxt('../../CVODE_result/1d/T500-0.8/postProcessing/sample/%s/data_T.xy'%(time))
b=np.loadtxt('../../3T_s0.5tau-aTY0.1P0.5-loss1e5/DNN_result/1d/T500-0.8/%s/data_T.xy'%(time))   #相对路径
Tem=np.empty(2000)
loc=np.empty(2000)
#print(a[:,1])
Tem=a[:,1]
loc=a[:,0]
TemD=np.empty(2000)
locD=np.empty(2000)
#print(a[:,1])
TemD=b[:,1]
locD=b[:,0]

# %%
#plt.title('c2h4-500K-0.8-2ms',fontsize=16)
plt.rcParams['xtick.direction'] = 'in'#将x轴的刻度线方向设置向内
plt.rcParams['ytick.direction'] = 'in'#将y轴的刻度线方向设置向内
plt.plot(loc*1000,Tem, linewidth=2,label='CVODE',color='black')
plt.scatter(locD*1000,TemD,marker='s',label='DNN',edgecolors='r',color='none')
plt.axis((0,40,400,2800))
#plt.ylim((800,2500))
plt.xticks((np.arange(-1,5)+1)*8,fontsize=16)
plt.yticks((np.arange(0,7)+1)*400,fontsize=16)
plt.minorticks_on()  #minor
plt.gca().xaxis.set_minor_locator(ticker.MultipleLocator(4))
plt.gca().yaxis.set_minor_locator(ticker.MultipleLocator(200))
plt.xlabel('x location[mm]',fontsize=19,fontweight='bold')  #加粗
plt.ylabel('Temperature[K]',fontsize=19,fontweight='bold')
plt.rcParams.update({'font.size': 20})
plt.legend(loc='upper left')
plt.savefig("../../../../graph/H2-0.8.png",dpi=300)

# %%
plt.rc('font',family='Times New Roman')  #指定全局字体
time=0.002
##选择时间点t
a=np.loadtxt('../../CVODE_result/1d/T500-0.9/postProcessing/sample/%s/data_T.xy'%(time))
b=np.loadtxt('../../3T_s0.5tau-aTY0.1P0.5-loss1e5/DNN_result/1d/T500-0.9/%s/data_T.xy'%(time))   #相对路径
Tem=np.empty(2000)
loc=np.empty(2000)
#print(a[:,1])
Tem=a[:,1]
loc=a[:,0]
TemD=np.empty(2000)
locD=np.empty(2000)
#print(a[:,1])
TemD=b[:,1]
locD=b[:,0]

# %%
#plt.title('c2h4-500K-0.8-2ms',fontsize=16)
plt.rcParams['xtick.direction'] = 'in'#将x轴的刻度线方向设置向内
plt.rcParams['ytick.direction'] = 'in'#将y轴的刻度线方向设置向内
plt.plot(loc*1000,Tem, linewidth=2,label='CVODE',color='black')
plt.scatter(locD*1000,TemD,marker='s',label='DNN',edgecolors='r',color='none')
plt.axis((0,40,400,2800))
#plt.ylim((800,2500))
plt.xticks((np.arange(-1,5)+1)*8,fontsize=16)
plt.yticks((np.arange(0,7)+1)*400,fontsize=16)
plt.minorticks_on()  #minor
plt.gca().xaxis.set_minor_locator(ticker.MultipleLocator(4))
plt.gca().yaxis.set_minor_locator(ticker.MultipleLocator(200))
plt.xlabel('x location[mm]',fontsize=19,fontweight='bold')  #加粗
plt.ylabel('Temperature[K]',fontsize=19,fontweight='bold')
plt.rcParams.update({'font.size': 20})
plt.legend(loc='upper left')
plt.savefig("../../../../graph/H2-0.9.png",dpi=300)

# %%
time=0.002
##选择时间点t
a=np.loadtxt('../../CVODE_result/1d/T500-1.0/postProcessing/sample/%s/data_T.xy'%(time))
b=np.loadtxt('../../3T_s0.5tau-aTY0.1P0.5-loss1e5/DNN_result/1d/T500-1.0/%s/data_T.xy'%(time))   #相对路径
Tem=np.empty(2000)
loc=np.empty(2000)
#print(a[:,1])
Tem=a[:,1]
loc=a[:,0]
TemD=np.empty(2000)
locD=np.empty(2000)
#print(a[:,1])
TemD=b[:,1]
locD=b[:,0]

# %%
#plt.title('c2h4-500K-0.8-2ms',fontsize=16)
plt.rcParams['xtick.direction'] = 'in'#将x轴的刻度线方向设置向内
plt.rcParams['ytick.direction'] = 'in'#将y轴的刻度线方向设置向内
plt.plot(loc*1000,Tem, linewidth=2,label='CVODE',color='black')
plt.scatter(locD*1000,TemD,marker='s',label='DNN',edgecolors='r',color='none')
plt.axis((0,40,400,2800))
#plt.ylim((800,2500))
plt.xticks((np.arange(-1,5)+1)*8,fontsize=16)
plt.yticks((np.arange(0,7)+1)*400,fontsize=16)
plt.minorticks_on()  #minor
plt.gca().xaxis.set_minor_locator(ticker.MultipleLocator(4))
plt.gca().yaxis.set_minor_locator(ticker.MultipleLocator(200))
plt.xlabel('x location[mm]',fontsize=19,fontweight='bold')  #加粗
plt.ylabel('Temperature[K]',fontsize=19,fontweight='bold')
plt.rcParams.update({'font.size': 20})
plt.legend(loc='upper left')
plt.savefig("../../../../graph/H2-1.0.png",dpi=300)

# %%
plt.rc('font',family='Times New Roman')  #指定全局字体
time=0.002
##选择时间点t
a=np.loadtxt('../../CVODE_result/1d/T500-1.1/postProcessing/sample/%s/data_T.xy'%(time))
b=np.loadtxt('../../3T_s0.5tau-aTY0.1P0.5-loss1e5/DNN_result/1d/T500-1.1/%s/data_T.xy'%(time))   #相对路径
Tem=np.empty(2000)
loc=np.empty(2000)
#print(a[:,1])
Tem=a[:,1]
loc=a[:,0]
TemD=np.empty(2000)
locD=np.empty(2000)
#print(a[:,1])
TemD=b[:,1]
locD=b[:,0]

# %%
#plt.title('c2h4-500K-0.8-2ms',fontsize=16)
plt.rcParams['xtick.direction'] = 'in'#将x轴的刻度线方向设置向内
plt.rcParams['ytick.direction'] = 'in'#将y轴的刻度线方向设置向内
plt.plot(loc*1000,Tem, linewidth=2,label='CVODE',color='black')
plt.scatter(locD*1000,TemD,marker='s',label='DNN',edgecolors='r',color='none')
plt.axis((0,40,400,2800))
#plt.ylim((800,2500))
plt.xticks((np.arange(-1,5)+1)*8,fontsize=16)
plt.yticks((np.arange(0,7)+1)*400,fontsize=16)
plt.minorticks_on()  #minor
plt.gca().xaxis.set_minor_locator(ticker.MultipleLocator(4))
plt.gca().yaxis.set_minor_locator(ticker.MultipleLocator(200))
plt.xlabel('x location[mm]',fontsize=19,fontweight='bold')  #加粗
plt.ylabel('Temperature[K]',fontsize=19,fontweight='bold')
plt.rcParams.update({'font.size': 20})
plt.legend(loc='upper left')
plt.savefig("../../../../graph/H2-1.1.png",dpi=300)

# %%
time=0.002
##选择时间点t
a=np.loadtxt('../../CVODE_result/1d/T500-1.2/postProcessing/sample/%s/data_T.xy'%(time))
b=np.loadtxt('../../3T_s0.5tau-aTY0.1P0.5-loss1e5/DNN_result/1d/T500-1.2/%s/data_T.xy'%(time))   #相对路径
loc=np.empty(2000)
#print(a[:,1])
Tem=a[:,1]
loc=a[:,0]
TemD=np.empty(2000)
locD=np.empty(2000)
#print(a[:,1])
TemD=b[:,1]
locD=b[:,0]

# %%
#plt.title('c2h4-500K-0.8-2ms',fontsize=16)
plt.rcParams['xtick.direction'] = 'in'#将x轴的刻度线方向设置向内
plt.rcParams['ytick.direction'] = 'in'#将y轴的刻度线方向设置向内
plt.plot(loc*1000,Tem, linewidth=2,label='CVODE',color='black')
plt.scatter(locD*1000,TemD,marker='s',label='DNN',edgecolors='red',color='none')
plt.axis((0,40,400,2800))
#plt.ylim((800,2500))
plt.xticks((np.arange(-1,5)+1)*8,fontsize=16)
plt.yticks((np.arange(0,7)+1)*400,fontsize=16)
plt.minorticks_on()  #minor
plt.gca().xaxis.set_minor_locator(ticker.MultipleLocator(4))
plt.gca().yaxis.set_minor_locator(ticker.MultipleLocator(200))
plt.xlabel('x location[mm]',fontsize=19,fontweight='bold')  #加粗
plt.ylabel('Temperature[K]',fontsize=19,fontweight='bold')
plt.rcParams.update({'font.size': 20})
plt.legend(loc='upper left')
plt.savefig("../../../../graph/H2-1.2.png",dpi=300)
